704,-0.2823253870010376,-0.7017643451690674,0.9714085459709167,0.6864282488822937,-0.5341581106185913,0.37132740020751953,-0.7502565383911133,-0.4879304766654968,0.8112576603889465,0.1785089671611786,-0.2220466434955597,0.2511211633682251,-0.3871617019176483,-0.4931943416595459,-0.14979016780853271,-0.7041701078414917,0.44421645998954773,-0.6706914305686951,0.8994383811950684,0.7469329237937927,0.06577928364276886,-0.12415161728858948,0.20801261067390442,0.2280462235212326,1.2837153673171997,0.6386026740074158,-0.792693555355072,0.4741680920124054,0.15146282315254211,1.4839613437652588,-0.9093307256698608,0.5869321823120117,-1.1224130392074585,-1.108128309249878,0.28051844239234924,-0.49388834834098816,0.5383670330047607,0.6994260549545288,-0.4343709945678711,-0.07007148861885071,0.10465897619724274,-0.3684103786945343,0.19661369919776917,-0.7608206272125244,1.0034716129302979,0.163721963763237,1.1542084217071533,-0.10554683208465576,0.4817714989185333,-0.4923645555973053,0.42432278394699097,0.9577971696853638,0.6067575216293335,-0.38511818647384644,-0.04290000721812248,-0.521575927734375,-0.9951764941215515,-0.38051721453666687,1.1798404455184937,-0.03187689930200577,0.27218693494796753,-0.5056644082069397,1.1121355295181274,0.3959621787071228,0.012082021683454514,0.3031080961227417,1.2061688899993896,-0.5463529229164124,-0.2944091260433197,-0.36816734075546265,-0.6847947239875793,-0.054897453635931015,-0.2000095248222351,-0.8060880303382874,-0.4056239426136017,-0.43079179525375366,-0.4036403298377991,0.6824712157249451,-0.3482135236263275,1.801698088645935,0.6753183007240295,1.203983187675476,0.22639746963977814,0.351374089717865,-0.9422283172607422,-0.11461962759494781,-1.069419026374817,1.0464112758636475,-0.2932978570461273,-1.088489055633545,-0.23413783311843872,-0.7519825100898743,-0.2423650026321411]

# %% [markdown]
# ### Get similarity from Neo4j

# %%
import time

start_time = time.time()
query = """WITH $targetEmbeddings AS targetEmbeddings
            MATCH (p:Publication)-[:HAS_FIELD_OF_STUDY]->(f:FieldOfStudy)
            WITH p, f, gds.similarity.cosine(p.embedding, targetEmbeddings) as similarity 
            WHERE similarity > 0.5
            RETURN p, f, similarity
            ORDER BY similarity DESC
            LIMIT 15"""

with driver.session() as session:
    result = session.run(query, targetEmbeddings=targetEmbeddings)

    for record in result:
        publication = record["p"]
        field = record["f"]
        similarity = record["similarity"]

print(f'Query time: {time.time() - start_time} seconds')

# %% [markdown]
# ### Connect to Weaviate Database

# %%
import weaviate

#client = weaviate.Client("http://0.0.0.0:8080")

client = weaviate.Client("http://localhost:8081")

#client.schema.delete_all()
client.schema.get()

# %%
# Perform a query to fetch details of publications
data = client.query.get(
    "Publication",  # Class name directly as a string
    ["subtopic", "neo4jID", "topic"]  # List of properties to retrieve
).with_limit(100).do()  # Adjust the limit as needed

# Assuming you want to print the results or process them further
print(data)

# %%
map_subtopic_label = {'Speech & Audio in NLP': 0,
                   'Multimodality': 0,
                   'Visual Data in NLP': 0,
                   'Structured Data in NLP': 0,
                   'Programming Languages in NLP': 0,
                   'Natural Language Interfaces': 1,
                   'Question Answering': 1,
                   'Dialogue Systems & Conversational Agents': 1,
                   'Semantic Text Processing': 2,
                   'Discourse & Pragmatics': 2,
                   'Representation Learning': 2,
                   'Knowledge Representation': 2,
                   'Text Complexity': 2,
                   'Semantic Search': 2,
                   'Representation Learning': 2,
                   'Word Sense Disambiguation': 2,
                   'Semantic Parsing': 2,
                   'Language Models': 2,
                   'Semantic Similarity': 2,
                   'Sentiment Analysis': 3,
                   'Opinion Mining': 3,
                   'Stylistic Analysis': 3,
                   'Intent Recognition': 3,
                   'Emotion Analysis': 3,
                   'Aspect-based Sentiment Analysis': 3,
                   'Polarity Analysis': 3,
                   'Syntactic Text Processing': 4,
                   'Tagging': 4,
                   'Morphology': 4,
                   'Chunking': 4,
                   'Phonology': 4,
                   'Text Error Correction': 4,
                   'Text Segmentation': 4,
                   'Typology': 4,
                   'Syntactic Parsing': 4,
                   'Phonetics': 4,
                   'Text Normalization': 4,
                   'Linguistics & Cognitive NLP': 5,
                   'Linguistic Theories': 5,
                   'Cognitive Modeling': 5,
                   'Psycholinguistics': 5,
                   'Responsible & Trustworthy NLP': 6,
                   'Responsible NLP': 6,
                   'Ethical NLP': 6,
                   'Low-Resource NLP': 6,
                   'Robustness in NLP': 6,
                   'Green & Sustainable NLP': 6,
                   'Explainability & Interpretability in NLP': 6,
                   'Reasoning': 7,
                   'Textual Inference': 7,
                   'Commonsense Reasoning': 7,
                   'Numerical Reasoning': 7,
                   'Knowledge Graph Reasoning': 7,
                   'Machine Reading Comprehension': 7,
                   'Fact & Claim Verification': 7,
                   'Argument Mining': 7,
                   'Multilinguality': 8,
                   'Cross-Lingual Transfer': 8,
                   'Machine Translation': 8,
                   'Code-Switching': 8,
                   'Typology': 8,
                   'Information Retrieval': 9,
                   'Indexing': 9,
                   'Document Retrieval': 9,
                   'Semantic Search': 9,
                   'Text Classification': 9,
                   'Passage Retrieval': 9,
                   'Information Extraction & Text Mining': 10,
                   'Coreference Resolution': 10,
                   'Text Clustering': 10,
                   'Named Entity Recognition': 10,
                   'Event Extraction': 10,
                   'Open Information Extraction': 10,
                   'Term Extraction': 10,
                   'Topic Modeling': 10,
                   'Relation Extraction': 10,
                   'Text Generation': 11,
                   'Data-to-Text Generation': 11,
                   'Question Generation': 11,
                   'Dialogue Response Generation': 11,
                   'Captioning': 11,
                   'Paraphrassing': 11,
                   'Paraphrasing': 11,
                   'Machine Translation': 11,
                   'Text Style Transfer': 11,
                   'Code Generation': 11,
                   'Summarization': 11,
                   'Speech Recognition': 11}

map_label_topic =  {
                    
                    0:'Multimodality',
                    1:'Natural Language Interfaces',
                    2:'Semantic Text Processing',
                    3:'Sentiment Analysis',
                    4:'Syntactic Text Processing',
                    5:'Linguistics & Cognitive NLP',
                    6:'Responsible NLP',
                    7:'Reasoning',
                    8:'Multilinguality',
                    9:'Information Retrieval',
                    10:'Information Extraction & Text Mining',
                    11:'Text Generation',
                   -1:'Random Question'
                }

main_topics = list(map_label_topic.values())

# %%
client.schema.create_class({'class': 'Publication',
                            'properties': [
                                {
                                    "dataType": ["text"],
                                    "name": "topic",
                                },
                                {
                                    "dataType": ["text"],
                                    "name": "neo4jID",
                                },
                                {
                                    "dataType": ["text"],
                                    "name": "subtopic",
                                },
                                {
                                    "dataType": ["int"],
                                    "name": "label",
                                },
                                {
                                    "dataType": ["text"],
                                    "name": "title",
                                },
                                {
                                    "dataType": ["text"],
                                    "name": "abstract",
                                },
                                {
                                    'name': 'cluster_tag',
                                    'dataType': ['text'],
                                },
                                {
                                    'name': 'cluster',
                                    'dataType': ['int'],
                                }
                            ],
                            'vectorIndexConfig': {
                                "distance": "cosine",
                                },
              ### Create Schema              
                           })
client.schema.get()

# %% [markdown]
# ### Transfer data from Neo4j to Weaviate

# %%
added = {}

# %%
from tqdm import tqdm
import time

batch_size = 500  # Adjust the batch size as per your requirements
batch_objects = 0

with driver.session() as session:
    results = session.run("MATCH (p:Publication)-[:HAS_FIELD_OF_STUDY]->(f:FieldOfStudy) RETURN p, f")

    for result in tqdm(results, total=355732):
        subtopic = result['f']['label']
        
        # Push only subtopics
        if subtopic not in main_topics:
            topic_label = map_subtopic_label[subtopic]
            topic = map_label_topic[topic_label]
            title = result['p']['publicationTitle']
            abstract = result['p']['publicationAbstract']
            neo4jID = str(result['p']._id)
            
            if not added.get(str(topic_label)+';'+neo4jID, False):
                cls_point = cluster_data[(cluster_data['title'] == title) & (cluster_data['topic'] == subtopic)]
                if len(cls_point) > 0:
                    cluster_tag = cls_point.iloc[0]['cluster_tag']
                    cluster = cls_point.iloc[0]['cluster']
                else:
                    cluster_tag = ''
                    cluster = 0

                client.batch.add_data_object(
                    {
                        'subtopic': subtopic,
                        'topic': topic,
                        'label': topic_label,
                        'title': title,
                        'abstract': abstract,
                        'cluster': cluster,
                        'cluster_tag': cluster_tag,
                        'neo4jID': neo4jID
                    },
                    'Publication',
                    vector= result['p']['embedding']
                )
                
                batch_objects += 1
                added[str(topic_label)+';'+neo4jID] = True

                if batch_objects >= batch_size:
                    client.batch.create_objects()
                    batch_objects = 0
            

# Create any remaining objects in the last batch
if batch_objects > 0:
    client.batch.create_objects()

# %%
with driver.session() as session:
    results = session.run("MATCH (p:Publication) WHERE ID(p) = 36220 RETURN p")
    
    for result in results:
        pub = result['p']
        print(pub)

# %% [markdown]
# ### Get similarity from Weaviate

# %%
import time

start_time = time.time()

publications = client.query.get("Publication", ["subtopic", "neo4jID"]) \
                        .with_where({"path": "topic", "operator": "Equal", "valueString": 'Linguistics & Cognitive NLP'}) \
                        .with_near_vector({"vector": targetEmbeddings, "distance": 0.5}) \
                        .with_additional(["distance"]).with_limit(15).do()

print()
print(f'Query time: {time.time() - start_time} seconds')

# %% [markdown]
# ### Add topic data to Weaviate for testing the similarity model

# %%
client.schema.create_class({'class': 'Topic',
                            'properties': [
                                {
                                    "dataType": ["text"],
                                    "name": "topic",
                                },
                                {
                                    "dataType": ["text"],
                                    "name": "neo4jID",
                                }
                            ],
                            'vectorIndexConfig': {
                                "distance": "cosine",
                            },
                           })
client.schema.get()

# %%
from tqdm import tqdm
import time

client.batch.configure(
    batch_size=1000,
    dynamic=True,
)

with client.batch as batch:
    with driver.session() as session:
        results = session.run("MATCH (p:Publication)-[:HAS_FIELD_OF_STUDY]->(f:FieldOfStudy) WHERE f.level = [1] RETURN p, f")

        for result in tqdm(results, total=196124):
            topic = result['f']['label']
            topic_label = map_subtopic_label[topic]
            
            # Push only subtopics
            if topic in main_topics:
                neo4jID = str(result['p']._id)

                batch.add_data_object(
                    {
                        'topic': topic,
                        'neo4jID': neo4jID
                    },
                    'Topic',
                    vector= result['p']['embedding']
                )
